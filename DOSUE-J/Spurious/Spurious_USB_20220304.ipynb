# %% [markdown]
# # Setting

# %%
outdir = './output_spurious'
csvType='Keysight'

import os
# Check output directory
if not os.path.isdir(outdir):
    print(f'Create a new directory for output files! --> {outdir}')
    os.mkdir(outdir)
    pass
# Out:
# Create a new directory for output files! --> ./output_spurious

# %% [markdown]
# # Import libraries

# %%
import os
import sys
sys.path.append(os.path.join(os.path.dirname('.'), '..'))
from utils import *

# %% [markdown]
# # Define function to read data & make plots

# %%
def read_and_plot(
    filename_list, label_list, suffix_list, color_list, suffix_all, outdir, 
    markersize=1.0, linestyle='', linewidth=0,
    xmin=None, xmax=None, ymin=None, ymax=None,
    figsize = (12, 2.5),
    ):
    # Check output directory
    if not os.path.isdir(outdir):
        print(f'Create a new directory for output files! --> {outdir}')
        os.mkdir(outdir)
        pass
    
    freq_list = []
    power_list = []
    for filename in filename_list:
        freq, power = read_csv(f'{filename}', csvType=csvType)
        freq_list.append(np.array(freq))
        power_list.append(np.array(power))
        pass
    
    # Select data between freq_min and freq_max
    for i, freq in enumerate(freq_list):
        power_list[i] = power_list[i][ (freq >= freq_min) & (freq <= freq_max) ]
        freq_list[i] = freq_list[i][ (freq >= freq_min) & (freq <= freq_max) ]
        pass
    
    # Plot each data
    for freq, power, label, suffix, color in zip(freq_list, power_list, label_list, suffix_list, color_list):
        '''
        plot_power(
            False, [freq], [power], [label], [color], f'{suffix}{suffix_all}', outdir,
            markersize=markersize, linestyle=linestyle, linewidth=linewidth, figsize=figsize,
            xmin=xmin, xmax=xmax, ymin=ymin, ymax=ymax)
        plot_power(
            False, [freq], [power], [label], [color], f'{suffix}{suffix_all}_logy', outdir, logy=True,
            markersize=markersize, linestyle=linestyle, linewidth=linewidth, figsize=figsize,
            xmin=xmin, xmax=xmax, ymin=ymin, ymax=ymax)
        '''
        plot_power(
            True, [freq], [power], [label], [color], f'{suffix}{suffix_all}', outdir,
            markersize=markersize, linestyle=linestyle, linewidth=linewidth, figsize=figsize,
            xmin=xmin, xmax=xmax, ymin=to_dB(ymin), ymax=to_dB(ymax))
        pass
    
    # Plot all datas
    suffix = '-'.join(suffix_list)
    if len(suffix)>50: suffix = suffix[:50]
    suffix += suffix_all
    '''
    plot_power(
        False, freq_list, power_list, label_list, color_list, suffix, outdir,
        markersize=markersize, linestyle=linestyle, linewidth=linewidth, figsize=figsize,
        xmin=xmin, xmax=xmax, ymin=ymin, ymax=ymax)
    plot_power(
        False, freq_list, power_list, label_list, color_list, f'{suffix}_logy', outdir, logy=True,
        markersize=markersize, linestyle=linestyle, linewidth=linewidth, figsize=figsize,
        xmin=xmin, xmax=xmax, ymin=ymin, ymax=ymax)
    '''
    plot_power(
        True, freq_list, power_list, label_list, color_list, f'{suffix}_logy', outdir,
        markersize=markersize, linestyle=linestyle, linewidth=linewidth, figsize=figsize,
        xmin=xmin, xmax=xmax, ymin=to_dB(ymin), ymax=to_dB(ymax))
          
    return

# %% [markdown]
# # Plot all the frequency range without Al plate

# %%
datadir_new = './../../../data/dosue-j_20220304/'
datadir_base = './../../../data/dosue-j_reference_20220303/'
filename_new = f'{datadir_new}/220304_002_noal_nophone_1.csv'
filename_base = f'{datadir_base}/220302_003_300K_without_allrECO.csv'
filename_base = f'{datadir_base}/220303_002_300Kz_without_allECO_100000.csv'
suffix_new = 'darkroom'
suffix_base = 'tandem'
suffix_all = '_fullrange'
freq_min = 0. # initial cut on freq
freq_max = 26.5 # initial cut on freq

read_and_plot(
    [filename_new, filename_base], [suffix_new, suffix_base], [suffix_new, suffix_base], ['tab:blue', 'tab:orange'], 
    suffix_all=suffix_all, outdir=outdir)

# %% [markdown]
# # 8-9GHz

# %%
datadir_new = './../../../data/dosue-j_20220304'
datadir_base = './../../../data/dosue-j_reference_20220303'
filename_new = f'{datadir_new}/220304_003_spurious_8-9GHz_wtSpeECO_1.csv'
filename_base = f'{datadir_base}/220303_002_300K_8_9GHz_without_allECO_rbw5k.csv'
suffix_new = 'darkroom'
suffix_base = 'tandem'
suffix_all = '_8-9GHz'
freq_min = 8. # initial cut on freq
freq_max = 9. # initial cut on freq

read_and_plot(
    [filename_new, filename_base], [suffix_new, suffix_base], [suffix_new, suffix_base], ['tab:blue', 'tab:orange'], 
    suffix_all=suffix_all, outdir=outdir)

# %% [markdown]
# # 9-10GHz

# %%
datadir_new = './../../../data/dosue-j_20220304'
datadir_base = './../../../data/dosue-j_reference_20220303'
filename_new = f'{datadir_new}/220304_003_spurious_9-10GHz_wtSpeECO_1.csv'
filename_base = f'{datadir_base}/220303_002_300K_9_10GHz_without_allECO_rbw5k.csv'
suffix_new = 'darkroom'
suffix_base = 'tandem'
suffix_all = '_9-10GHz'
freq_min = 9. # initial cut on freq
freq_max = 10. # initial cut on freq

read_and_plot(
    [filename_new, filename_base], [suffix_new, suffix_base], [suffix_new, suffix_base], ['tab:blue', 'tab:orange'], 
    suffix_all=suffix_all, outdir=outdir)

# %% [markdown]
# # 10-11GHz

# %%
datadir_new = './../../../data/dosue-j_20220304'
datadir_base = './../../../data/dosue-j_reference_20220303'
filename_new = f'{datadir_new}/220304_003_spurious_10-11GHz_wtSpeECO_1.csv'
filename_base = f'{datadir_base}/220303_002_300K_10_11GHz_without_allECO_rbw5k.csv'
suffix_new = 'darkroom'
suffix_base = 'tandem'
suffix_all = '10-11GHz'
freq_min = 10. # initial cut on freq
freq_max = 11. # initial cut on freq

read_and_plot(
    [filename_new, filename_base], [suffix_new, suffix_base], [suffix_new, suffix_base], ['tab:blue', 'tab:orange'], 
    suffix_all=suffix_all, outdir=outdir)

# %% [markdown]
# # 11-12GHz

# %%
datadir_new = './../../../data/dosue-j_20220304'
datadir_base = './../../../data/dosue-j_reference_20220303'
filename_new = f'{datadir_new}/220304_003_spurious_11-12GHz_wtSpeECO_1.csv'
filename_base = f'{datadir_base}/220303_002_300K_11_12GHz_without_allECO_rbw5k.csv'
suffix_new = 'darkroom'
suffix_base = 'tandem'
suffix_all = '_11-12GHz'
freq_min = 11. # initial cut on freq
freq_max = 12. # initial cut on freq

read_and_plot(
    [filename_new, filename_base], [suffix_new, suffix_base], [suffix_new, suffix_base], ['tab:blue', 'tab:orange'], 
    suffix_all=suffix_all, outdir=outdir)

# %% [markdown]
# # 12-13GHz

# %%
datadir_new = './../../../data/dosue-j_20220304'
datadir_base = './../../../data/dosue-j_reference_20220303'
filename_new = f'{datadir_new}/220304_003_spurious_12-13GHz_wtSpeECO_1.csv'
filename_base = f'{datadir_base}/220303_002_300K_12_13GHz_without_allECO_rbw5k.csv'
suffix_new = 'darkroom'
suffix_base = 'tandem'
suffix_all = '_12-13GHz'
freq_min = 12. # initial cut on freq
freq_max = 13. # initial cut on freq

read_and_plot(
    [filename_new, filename_base], [suffix_new, suffix_base], [suffix_new, suffix_base], ['tab:blue', 'tab:orange'], 
    suffix_all=suffix_all, outdir=outdir)

# %% [markdown]
# # 9.6 GHz

# %%
datadir_new = './../../../data/dosue-j_20220304'
datadir_base = './../../../data/dosue-j_reference_20220303'
filename_new = f'{datadir_new}/220304_003_spurious_9-10GHz_wtSpeECO_1.csv'
filename_base = f'{datadir_base}/220303_002_300K_9_10GHz_without_allECO_rbw5k.csv'
suffix_new = 'darkroom'
suffix_base = 'tandem'
suffix_all = '_9.6GHz'
freq_min = 9.59 # initial cut on freq
freq_max = 9.61 # initial cut on freq

read_and_plot(
    [filename_new, filename_base], [suffix_new, suffix_base], [suffix_new, suffix_base], ['tab:blue', 'tab:orange'], 
    markersize = 2, linestyle='-', linewidth=0.5,
    suffix_all=suffix_all, outdir=outdir)

# %% [markdown]
# # 10 GHz

# %%
datadir_new = './../../../data/dosue-j_20220304'
datadir_base = './../../../data/dosue-j_reference_20220303'
filename_new = f'{datadir_new}/220304_003_spurious_10-11GHz_wtSpeECO_1.csv'
filename_base = f'{datadir_base}/220303_002_300K_10_11GHz_without_allECO_rbw5k.csv'
suffix_new = 'darkroom'
suffix_base = 'tandem'
suffix_all = '_10GHz'
freq_min = 10. # initial cut on freq
freq_max = 10.01 # initial cut on freq

read_and_plot(
    [filename_new, filename_base], [suffix_new, suffix_base], [suffix_new, suffix_base], ['tab:blue', 'tab:orange'], 
    markersize = 2, linestyle='-', linewidth=0.5,
    suffix_all=suffix_all, outdir=outdir)
