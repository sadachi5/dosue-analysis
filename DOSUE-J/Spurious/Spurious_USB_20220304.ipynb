# %% [markdown]
# # Setting

# %%
outdir = './output'
csvType='Keysight'

import os
# Check output directory
if not os.path.isdir(outdir):
    print(f'Create a new directory for output files! --> {outdir}')
    os.mkdir(outdir)
    pass

# %% [markdown]
# # Import libraries

# %%
import os
import sys
sys.path.append(os.path.join(os.path.dirname('.'), '..'))
from utils import *

# %% [markdown]
# # Define function to read data & make plots

# %%
def read_and_plot(
    filename_list, label_list, suffix_list, color_list, suffix_all, outdir, 
    markersize=1.0, linestyle='', linewidth=0,
    xmin=None, xmax=None, ymin=None, ymax=None
    ):
    figsize = (12, 2.5)
    freq_list = []
    power_list = []
    for filename in filename_list:
        freq, power = read_csv(f'{filename}', csvType=csvType)
        freq_list.append(np.array(freq))
        power_list.append(np.array(power))
        pass
    
    # Select data between freq_min and freq_max
    for i, freq in enumerate(freq_list):
        power_list[i] = power_list[i][ (freq >= freq_min) & (freq <= freq_max) ]
        freq_list[i] = freq_list[i][ (freq >= freq_min) & (freq <= freq_max) ]
        pass
    
    # Plot each data
    for freq, power, label, suffix, color in zip(freq_list, power_list, label_list, suffix_list, color_list):
        plot_power(
            False, [freq], [power], [label], [color], f'{suffix}{suffix_all}', outdir,
            markersize=markersize, linestyle=linestyle, linewidth=linewidth, figsize=figsize,
            xmin=xmin, xmax=xmax, ymin=ymin, ymax=ymax)
        plot_power(
            False, [freq], [power], [label], [color], f'{suffix}{suffix_all}_logy', outdir, logy=True,
            markersize=markersize, linestyle=linestyle, linewidth=linewidth, figsize=figsize,
            xmin=xmin, xmax=xmax, ymin=ymin, ymax=ymax)
        plot_power(
            True, [freq], [power], [label], [color], f'{suffix}{suffix_all}', outdir,
            markersize=markersize, linestyle=linestyle, linewidth=linewidth, figsize=figsize,
            xmin=xmin, xmax=xmax, ymin=to_dB(ymin), ymax=to_dB(ymax))
        pass
    
    # Plot all datas
    plot_power(
        False, freq_list, power_list, label_list, color_list, '-'.join(suffix_list)+f'{suffix_all}', outdir,
        markersize=markersize, linestyle=linestyle, linewidth=linewidth, figsize=figsize,
        xmin=xmin, xmax=xmax, ymin=ymin, ymax=ymax)
    plot_power(
        False, freq_list, power_list, label_list, color_list, '-'.join(suffix_list)+f'{suffix_all}_logy', outdir, logy=True,
        markersize=markersize, linestyle=linestyle, linewidth=linewidth, figsize=figsize,
        xmin=xmin, xmax=xmax, ymin=ymin, ymax=ymax)
    plot_power(
        True, freq_list, power_list, label_list, color_list, '-'.join(suffix_list)+f'{suffix_all}_logy', outdir,
        markersize=markersize, linestyle=linestyle, linewidth=linewidth, figsize=figsize,
        xmin=xmin, xmax=xmax, ymin=to_dB(ymin), ymax=to_dB(ymax))
          
    return

# %% [markdown]
# # Plot all the frequency range

# %%
datadir_new = './../data_20220303'
datadir_base = './../data_20220303'
filename_new = f'{datadir_new}/220302_002_300K_without_upperECO.csv'
filename_base = f'{datadir_base}/220302_003_300K_without_allrECO.csv'
suffix_new = 'darkroom'
suffix_base = 'tandem'
freq_min = 0. # initial cut on freq
freq_max = 26.5 # initial cut on freq

read_and_plot(
    [filename_new, filename_base], [suffix_new, suffix_base], [suffix_new, suffix_base], ['tab:blue', 'tab:orange'], 
    suffix_all='', outdir=outdir)

# %% [markdown]
# # 8-9GHz

# %%
datadir_new = './../data_20220303'
datadir_base = './../data_20220303'
filename_new = f'{datadir_new}/220302_004_300K_8_9GHz.csv'
filename_base = f'{datadir_base}/220302_004_300K_8_9GHz_without_allECO.csv'
suffix_new = 'darkroom'
suffix_base = 'tandem'
freq_min = 8. # initial cut on freq
freq_max = 9. # initial cut on freq

read_and_plot(
    [filename_new, filename_base], [suffix_new, suffix_base], [suffix_new, suffix_base], ['tab:blue', 'tab:orange'], 
    suffix_all='', outdir=outdir)

# %% [markdown]
# # 9-10GHz

# %%
datadir_new = './../data_20220303'
datadir_base = './../data_20220303'
filename_new = f'{datadir_new}/220302_004_300K_9_10GHz.csv'
filename_base = f'{datadir_base}/220302_004_300K_9_10GHz_without_allECO.csv'
suffix_new = 'darkroom'
suffix_base = 'tandem'
freq_min = 9. # initial cut on freq
freq_max = 10. # initial cut on freq

read_and_plot(
    [filename_new, filename_base], [suffix_new, suffix_base], [suffix_new, suffix_base], ['tab:blue', 'tab:orange'], 
    suffix_all='', outdir=outdir)

# %% [markdown]
# # 10-11GHz

# %%
datadir_new = './../data_20220303'
datadir_base = './../data_20220303'
filename_new = f'{datadir_new}/220302_004_300K_10_11GHz.csv'
filename_base = f'{datadir_base}/220302_004_300K_10_11GHz_without_allECO.csv'
suffix_new = 'darkroom'
suffix_base = 'tandem'
freq_min = 10. # initial cut on freq
freq_max = 11. # initial cut on freq

read_and_plot(
    [filename_new, filename_base], [suffix_new, suffix_base], [suffix_new, suffix_base], ['tab:blue', 'tab:orange'], 
    suffix_all='', outdir=outdir)

# %%
datadir_new = './../data_20220303'
datadir_base = './../data_20220303'
filename_new = f'{datadir_new}/220302_004_300K_10_11GHz.csv'
filename_base = f'{datadir_base}/220302_004_300K_10_11GHz_without_allECO.csv'
suffix_new = 'darkroom'
suffix_base = 'tandem'
freq_min = 10. # initial cut on freq
freq_max = 11. # initial cut on freq

read_and_plot(
    [filename_new, filename_base], [suffix_new, suffix_base], [suffix_new, suffix_base], ['tab:blue', 'tab:orange'], 
    suffix_all='', outdir=outdir)

# %% [markdown]
# # 11-12GHz

# %% [markdown]
# # 11-11.1GHz

# %%
datadir_new = './../data_20220303'
datadir_base = './../data_20220303'
filename_new = f'{datadir_new}/220302_004_300K_11_12GHz.csv'
filename_base = f'{datadir_base}/220302_004_300K_11_12GHz_without_allECO.csv'
suffix_new = 'darkroom'
suffix_base = 'tandem'
freq_min = 11. # initial cut on freq
freq_max = 11.1 # initial cut on freq

read_and_plot(
    [filename_new, filename_base], [suffix_new, suffix_base], [suffix_new, suffix_base], ['tab:blue', 'tab:orange'], 
    suffix_all='', outdir=outdir)

# %% [markdown]
# # 9.6 GHz

# %%
datadir_new = './../data_20220303'
datadir_base = './../data_20220303'
filename_new = f'{datadir_new}/220302_004_300K_9_10GHz.csv'
filename_base = f'{datadir_base}/220302_004_300K_9_10GHz_without_allECO.csv'
suffix_new = 'darkroom'
suffix_base = 'tandem'
freq_min = 9.5995 # initial cut on freq
freq_max = 9.6005 # initial cut on freq

read_and_plot(
    [filename_new, filename_base], [suffix_new, suffix_base], [suffix_new, suffix_base], ['tab:blue', 'tab:orange'], 
    markersize=2,
    suffix_all='', outdir=outdir)
